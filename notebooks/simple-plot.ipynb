# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\kirst\OneDrive\Desktop\Sprint6_TaylorsVersion\taylor_swift_songs.csv')
data.head()
# Out:
#      album_name album_release  track_number              track_name  \
# 0  Taylor Swift    2006-10-24             1              Tim McGraw
# 1  Taylor Swift    2006-10-24             2         Picture To Burn
# 2  Taylor Swift    2006-10-24             3  Teardrops On My Guitar
# 3  Taylor Swift    2006-10-24             4   A Place In This World
# 4  Taylor Swift    2006-10-24             5             Cold As You
#
#          artist featuring  bonus_track promotional_release single_release  \
# 0  Taylor Swift       NaN        False                 NaN     2006-06-19
# 1  Taylor Swift       NaN        False                 NaN     2008-02-03
# 2  Taylor Swift       NaN        False                 NaN     2007-02-19
# 3  Taylor Swift       NaN        False                 NaN            NaN
# 4  Taylor Swift       NaN        False                 NaN            NaN
#
#   track_release  ...  instrumentalness  liveness  valence    tempo  \
# ...

# %%
sns.histplot(data=data, x="valence");
